# %% [markdown]
# # Ingest constructors.json file
# 1. Read the file using Spark DataFrame Reader API
# 1. Add Metadata Columns:
#     - Source Files
#     - Timestamp
# 1. Write to Bronze delta table

# %%
# %run ../00-common/01.environment-config

# %%
# %run ../00-common/02.bronze-helpers

# %%
source_file = f"{landing_folder_path}/constructors.json"
table_name = f"{catalog_name}.{bronze_schema}.constructors"

# %% [markdown]
# #### Step 1: Read the json file using the dataframe reader API

# %%
#Define Schema

constructors_schema = 'constructorId STRING, name STRING, nationality STRING, url STRING'

# %%
#Read the Constructors file

constructors_df = (
    spark.read
        .format('json')
        .schema(constructors_schema)
        .option('mode', 'FAILFAST')
        .load(source_file)
)

# %%
display(constructors_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>constructorId</th><th>name</th><th>nationality</th><th>url</th></tr></thead><tbody><tr><td>adams</td><td>Adams</td><td>american</td><td>http://en.wikipedia.org/wiki/Adams_(constructor)</td></tr><tr><td>afm</td><td>AFM</td><td>german</td><td>http://en.wikipedia.org/wiki/Alex_von_Falkenhausen_Motorenbau</td></tr><tr><td>ags</td><td>AGS</td><td>french</td><td>http://en.wikipedia.org/wiki/Automobiles_Gonfaronnaises_Sportives</td></tr><tr><td>alfa</td><td>Alfa Romeo</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One</td></tr><tr><td>alphatauri</td><td>AlphaTauri</td><td>italian</td><td>http://en.wikipedia.org/wiki/Scuderia_AlphaTauri</td></tr><tr><td>alpine</td><td>Alpine F1 Team</td><td>french</td><td>http://en.wikipedia.org/wiki/Alpine_F1_Team</td></tr><tr><td>alta</td><td>Alta</td><td>british</td><td>http://en.wikipedia.org/wiki/Alta_auto_racing_team</td></tr><tr><td>amon</td><td>Amon</td><td>new zealander</td><td>http://en.wikipedia.org/wiki/Amon_(Formula_One_team)</td></tr><tr><td>apollon</td><td>Apollon</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Apollon_(Formula_One)</td></tr><tr><td>arrows</td><td>Arrows</td><td>british</td><td>http://en.wikipedia.org/wiki/Arrows_Grand_Prix_International</td></tr><tr><td>arzani-volpini</td><td>Arzani-Volpini</td><td>italian</td><td>http://en.wikipedia.org/wiki/Arzani-Volpini</td></tr><tr><td>aston_martin</td><td>Aston Martin</td><td>british</td><td>http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One</td></tr><tr><td>ats</td><td>ATS</td><td>italian</td><td>http://en.wikipedia.org/wiki/ATS_(wheels)</td></tr><tr><td>audi</td><td>Audi</td><td>german</td><td>null</td></tr><tr><td>bar</td><td>BAR</td><td>british</td><td>http://en.wikipedia.org/wiki/British_American_Racing</td></tr><tr><td>behra-porsche</td><td>Behra-Porsche</td><td>italian</td><td>http://en.wikipedia.org/wiki/Behra-Porsche</td></tr><tr><td>bellasi</td><td>Bellasi</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Bellasi</td></tr><tr><td>benetton</td><td>Benetton</td><td>italian</td><td>http://en.wikipedia.org/wiki/Benetton_Formula</td></tr><tr><td>bmw</td><td>BMW</td><td>german</td><td>http://en.wikipedia.org/wiki/BMW</td></tr><tr><td>bmw_sauber</td><td>BMW Sauber</td><td>german</td><td>http://en.wikipedia.org/wiki/BMW_Sauber</td></tr><tr><td>boro</td><td>Boro</td><td>dutch</td><td>http://en.wikipedia.org/wiki/Boro_(Formula_One)</td></tr><tr><td>brabham</td><td>Brabham</td><td>british</td><td>http://en.wikipedia.org/wiki/Brabham</td></tr><tr><td>brabham-alfa_romeo</td><td>Brabham-Alfa Romeo</td><td>british</td><td>http://en.wikipedia.org/wiki/Brabham</td></tr><tr><td>brabham-brm</td><td>Brabham-BRM</td><td>british</td><td>http://en.wikipedia.org/wiki/Brabham</td></tr><tr><td>brabham-climax</td><td>Brabham-Climax</td><td>british</td><td>http://en.wikipedia.org/wiki/Brabham</td></tr><tr><td>brabham-ford</td><td>Brabham-Ford</td><td>british</td><td>http://en.wikipedia.org/wiki/Brabham</td></tr><tr><td>brabham-repco</td><td>Brabham-Repco</td><td>british</td><td>http://en.wikipedia.org/wiki/Brabham</td></tr><tr><td>brawn</td><td>Brawn</td><td>british</td><td>http://en.wikipedia.org/wiki/Brawn_GP</td></tr><tr><td>brm</td><td>BRM</td><td>british</td><td>http://en.wikipedia.org/wiki/BRM</td></tr><tr><td>brm-ford</td><td>BRM-Ford</td><td>british</td><td>http://en.wikipedia.org/wiki/BRM</td></tr><tr><td>bromme</td><td>Bromme</td><td>american</td><td>http://en.wikipedia.org/wiki/Bromme</td></tr><tr><td>brp</td><td>BRP</td><td>british</td><td>http://en.wikipedia.org/wiki/British_Racing_Partnership</td></tr><tr><td>bugatti</td><td>Bugatti</td><td>french</td><td>http://en.wikipedia.org/wiki/Bugatti</td></tr><tr><td>butterworth</td><td>Aston Butterworth</td><td>british</td><td>http://en.wikipedia.org/wiki/Aston_Butterworth</td></tr><tr><td>cadillac</td><td>Cadillac F1 Team</td><td>american ...

# %% [markdown]
# #### Step 2: Add Metadata Columns
#  - Source File
#  - Ingestion Timestamp

# %%
constructors_final_df = add_ingestion_metadata(constructors_df)

# %% [markdown]
# ####Step 3: Write to Bronze Delta Table

# %%
(
    constructors_final_df
    .write
    .format('delta')
    .mode('overwrite')
    .saveAsTable(table_name)
)

# %%
display(spark.table(table_name))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>constructorId</th><th>name</th><th>nationality</th><th>url</th><th>ingestion_timestamp</th><th>source_file</th></tr></thead><tbody><tr><td>adams</td><td>Adams</td><td>american</td><td>http://en.wikipedia.org/wiki/Adams_(constructor)</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>afm</td><td>AFM</td><td>german</td><td>http://en.wikipedia.org/wiki/Alex_von_Falkenhausen_Motorenbau</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>ags</td><td>AGS</td><td>french</td><td>http://en.wikipedia.org/wiki/Automobiles_Gonfaronnaises_Sportives</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alfa</td><td>Alfa Romeo</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alphatauri</td><td>AlphaTauri</td><td>italian</td><td>http://en.wikipedia.org/wiki/Scuderia_AlphaTauri</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alpine</td><td>Alpine F1 Team</td><td>french</td><td>http://en.wikipedia.org/wiki/Alpine_F1_Team</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alta</td><td>Alta</td><td>british</td><td>http://en.wikipedia.org/wiki/Alta_auto_racing_team</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>amon</td><td>Amon</td><td>new zealander</td><td>http://en.wikipedia.org/wiki/Amon_(Formula_One_team)</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>apollon</td><td>Apollon</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Apollon_(Formula_One)</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>arrows</td><td>Arrows</td><td>british</td><td>http://en.wikipedia.org/wiki/Arrows_Grand_Prix_International</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>arzani-volpini</td><td>Arzani-Volpini</td><td>italian</td><td>http://en.wikipedia.org/wiki/Arzani-Volpini</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>aston_martin</td><td>Aston Martin</td><td>british</td><td>http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>ats</td><td>ATS</td><td>italian</td><td>http://en.wikipedia.org/wiki/ATS_(wheels)</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>audi</td><td>Audi</td><td>german</td><td>null</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bar</td><td>BAR</td><td>british</td><td>http://en.wikipedia.org/wiki/British_American_Racing</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>behra-porsche</td><td>Behra-Porsche</td><td>italian</td><td>http://en.wikipedia.org/wiki/Behra-Porsche</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bellasi</td><td>Bellasi</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Bellasi</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>benetton</td><td>Benetton</td><td>italian</td><td>http://en.wikipedia.org/wiki/Benetton_Formula</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</t ...
