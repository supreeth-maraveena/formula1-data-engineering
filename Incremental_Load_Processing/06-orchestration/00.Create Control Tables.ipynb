# %% [markdown]
# ##Create Control Tables

# %% [markdown]
# ![image_1785996109424.png](./image_1785996109424.png "image_1785996109424.png")

# %%
# %run ../00-common/01.environment-config

# %%
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.{control_schema}")
# Out:
# DataFrame[]

# %%
spark.sql(f"""
          CREATE TABLE IF NOT EXISTS {catalog_name}.{control_schema}.batch_control(
                batch_id STRING,
                status STRING,
                created_timestamp TIMESTAMP,
                updated_timestamp TIMESTAMP
            )
""")
# Out:
# DataFrame[]

# %%
# %sql
SELECT * FROM formula1_incr.control.batch_control;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>batch_id</th><th>status</th><th>created_timestamp</th><th>updated_timestamp</th></tr></thead><tbody><tr><td>2025-02</td><td>COMPLETED</td><td>2026-08-06T15:41:28.852Z</td><td>2026-08-06T15:54:18.741Z</td></tr><tr><td>2025-01</td><td>COMPLETED</td><td>2026-08-06T15:27:48.047Z</td><td>2026-08-06T15:38:03.896Z</td></tr></tbody></table></div>
