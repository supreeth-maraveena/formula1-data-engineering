# %% [markdown]
# ##Transform Constructors Data
#
# 1. Read bronze constructors table
# 2. Keep only the columns required for analytics (Drop url column)
# 3. Standardise column names using snake_case (constructorsId->constructors_id)
# 4. Rename columns to make them more meaningful (name->constructors_name)
# 5. Remove duplicate records
# 6. Transform values of columns nationality to Title Case
# 7. Write the transformed data to silver constructors table

# %%
# %run ../00-common/01.environment-config

# %%
bronze_table = f"{catalog_name}.{bronze_schema}.constructors"
silver_table = f"{catalog_name}.{silver_schema}.constructors"

# %% [markdown]
# ####Step 1: Read the bronze constructors table

# %%
constructors_df = spark.read.table(bronze_table)

# %%
display(constructors_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>constructorId</th><th>name</th><th>nationality</th><th>url</th><th>ingestion_timestamp</th><th>source_file</th></tr></thead><tbody><tr><td>adams</td><td>Adams</td><td>american</td><td>http://en.wikipedia.org/wiki/Adams_(constructor)</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>afm</td><td>AFM</td><td>german</td><td>http://en.wikipedia.org/wiki/Alex_von_Falkenhausen_Motorenbau</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>ags</td><td>AGS</td><td>french</td><td>http://en.wikipedia.org/wiki/Automobiles_Gonfaronnaises_Sportives</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alfa</td><td>Alfa Romeo</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alphatauri</td><td>AlphaTauri</td><td>italian</td><td>http://en.wikipedia.org/wiki/Scuderia_AlphaTauri</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alpine</td><td>Alpine F1 Team</td><td>french</td><td>http://en.wikipedia.org/wiki/Alpine_F1_Team</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alta</td><td>Alta</td><td>british</td><td>http://en.wikipedia.org/wiki/Alta_auto_racing_team</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>amon</td><td>Amon</td><td>new zealander</td><td>http://en.wikipedia.org/wiki/Amon_(Formula_One_team)</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>apollon</td><td>Apollon</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Apollon_(Formula_One)</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>arrows</td><td>Arrows</td><td>british</td><td>http://en.wikipedia.org/wiki/Arrows_Grand_Prix_International</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>arzani-volpini</td><td>Arzani-Volpini</td><td>italian</td><td>http://en.wikipedia.org/wiki/Arzani-Volpini</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>aston_martin</td><td>Aston Martin</td><td>british</td><td>http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>ats</td><td>ATS</td><td>italian</td><td>http://en.wikipedia.org/wiki/ATS_(wheels)</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>audi</td><td>Audi</td><td>german</td><td>null</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bar</td><td>BAR</td><td>british</td><td>http://en.wikipedia.org/wiki/British_American_Racing</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>behra-porsche</td><td>Behra-Porsche</td><td>italian</td><td>http://en.wikipedia.org/wiki/Behra-Porsche</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bellasi</td><td>Bellasi</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Bellasi</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>benetton</td><td>Benetton</td><td>italian</td><td>http://en.wikipedia.org/wiki/Benetton_Formula</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</t ...

# %% [markdown]
# ####Step 2: Keep only the coluumns required for analysis (Drop url column)
#
# There are 2 ways to do this... one by selecting the required columns and the other by dropping the unwanted columns

# %%
##This method uses dropping of the non-required columns
from pyspark.sql import functions as F

constructors_dropped_df = constructors_df.drop("url")

display(constructors_dropped_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-7052438962718799>, line 4
#       1 ##This method uses dropping of the non-required columns
#       2 from pyspark.sql import functions as F
# ----> 4 constructors_dropped_df = constructors_df.drop("url")
#       6 display(constructors_dropped_df)
#
# NameError: name 'constructors_df' is not defined

# %% [markdown]
# ####Step 3,4: Standardizing Column names
#
#  - Standardize column names using snake_case
#  - Rename column names to make them meaningful

# %%
constructors_renamed_df = (
    constructors_dropped_df
        .withColumnsRenamed({
            "constructorId": "constructor_id",
            "name": "constructor_name"})
)

# %%
display(constructors_renamed_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>constructor_id</th><th>constructor_name</th><th>nationality</th><th>ingestion_timestamp</th><th>source_file</th></tr></thead><tbody><tr><td>adams</td><td>Adams</td><td>american</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>afm</td><td>AFM</td><td>german</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>ags</td><td>AGS</td><td>french</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alfa</td><td>Alfa Romeo</td><td>swiss</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alphatauri</td><td>AlphaTauri</td><td>italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alpine</td><td>Alpine F1 Team</td><td>french</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alta</td><td>Alta</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>amon</td><td>Amon</td><td>new zealander</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>apollon</td><td>Apollon</td><td>swiss</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>arrows</td><td>Arrows</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>arzani-volpini</td><td>Arzani-Volpini</td><td>italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>aston_martin</td><td>Aston Martin</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>ats</td><td>ATS</td><td>italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>audi</td><td>Audi</td><td>german</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bar</td><td>BAR</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>behra-porsche</td><td>Behra-Porsche</td><td>italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bellasi</td><td>Bellasi</td><td>swiss</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>benetton</td><td>Benetton</td><td>italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bmw</td><td>BMW</td><td>german</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bmw_sauber</td><td>BMW Sauber</td><td>german</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>boro</td><td>Boro</td><td>dutch</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham</td><td>Brabham</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham-alfa_romeo</td><td>Brabham-Alfa Romeo</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham-brm</td><td>Brabham-BRM</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham-climax</td><td>Brabham-Climax</td><td>british</td><t ...

# %% [markdown]
# ####Step 5: Remove duplicate records

# %%
constructors_distinct_df = constructors_renamed_df.dropDuplicates(["constructor_id"])

# %%
display(constructors_distinct_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>constructor_id</th><th>constructor_name</th><th>nationality</th><th>ingestion_timestamp</th><th>source_file</th></tr></thead><tbody><tr><td>adams</td><td>Adams</td><td>american</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>afm</td><td>AFM</td><td>german</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>ags</td><td>AGS</td><td>french</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alfa</td><td>Alfa Romeo</td><td>swiss</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alphatauri</td><td>AlphaTauri</td><td>italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alpine</td><td>Alpine F1 Team</td><td>french</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alta</td><td>Alta</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>amon</td><td>Amon</td><td>new zealander</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>apollon</td><td>Apollon</td><td>swiss</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>arrows</td><td>Arrows</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>arzani-volpini</td><td>Arzani-Volpini</td><td>italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>aston_martin</td><td>Aston Martin</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>ats</td><td>ATS</td><td>italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>audi</td><td>Audi</td><td>german</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bar</td><td>BAR</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>behra-porsche</td><td>Behra-Porsche</td><td>italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bellasi</td><td>Bellasi</td><td>swiss</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>benetton</td><td>Benetton</td><td>italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bmw</td><td>BMW</td><td>german</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bmw_sauber</td><td>BMW Sauber</td><td>german</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>boro</td><td>Boro</td><td>dutch</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham</td><td>Brabham</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham-alfa_romeo</td><td>Brabham-Alfa Romeo</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham-brm</td><td>Brabham-BRM</td><td>british</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham-climax</td><td>Brabham-Climax</td><td>british</td><t ...

# %% [markdown]
# ####Step 6: Transform the values of nationality to Title Case

# %%
constructors_final_df = (
    constructors_distinct_df
        .withColumn("nationality", F.initcap(F.col("nationality")))
)

display(constructors_final_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>constructor_id</th><th>constructor_name</th><th>nationality</th><th>ingestion_timestamp</th><th>source_file</th></tr></thead><tbody><tr><td>adams</td><td>Adams</td><td>American</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>afm</td><td>AFM</td><td>German</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>ags</td><td>AGS</td><td>French</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alfa</td><td>Alfa Romeo</td><td>Swiss</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alphatauri</td><td>AlphaTauri</td><td>Italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alpine</td><td>Alpine F1 Team</td><td>French</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alta</td><td>Alta</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>amon</td><td>Amon</td><td>New Zealander</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>apollon</td><td>Apollon</td><td>Swiss</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>arrows</td><td>Arrows</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>arzani-volpini</td><td>Arzani-Volpini</td><td>Italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>aston_martin</td><td>Aston Martin</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>ats</td><td>ATS</td><td>Italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>audi</td><td>Audi</td><td>German</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bar</td><td>BAR</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>behra-porsche</td><td>Behra-Porsche</td><td>Italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bellasi</td><td>Bellasi</td><td>Swiss</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>benetton</td><td>Benetton</td><td>Italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bmw</td><td>BMW</td><td>German</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bmw_sauber</td><td>BMW Sauber</td><td>German</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>boro</td><td>Boro</td><td>Dutch</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham</td><td>Brabham</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham-alfa_romeo</td><td>Brabham-Alfa Romeo</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham-brm</td><td>Brabham-BRM</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham-climax</td><td>Brabham-Climax</td><td>British</td><t ...

# %% [markdown]
# ####Step 7: Write the transformed data to the silver 'constructors' table

# %%
(
    constructors_final_df
        .write
        .mode("overwrite")
        .format("delta")
        .saveAsTable(silver_table)
)

# %%
display(spark.table(silver_table))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>constructor_id</th><th>constructor_name</th><th>nationality</th><th>ingestion_timestamp</th><th>source_file</th></tr></thead><tbody><tr><td>ats</td><td>ATS</td><td>Italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>benetton</td><td>Benetton</td><td>Italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bmw</td><td>BMW</td><td>German</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>brabham-repco</td><td>Brabham-Repco</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>cadillac</td><td>Cadillac F1 Team</td><td>American</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>force_india</td><td>Force India</td><td>Indian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>lotus-pw</td><td>Lotus-Pratt &amp; Whitney</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>osella</td><td>Osella</td><td>Italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>token</td><td>Token</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>amon</td><td>Amon</td><td>New Zealander</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>cooper-alfa_romeo</td><td>Cooper-Alfa Romeo</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>cooper-borgward</td><td>Cooper-Borgward</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>dallara</td><td>Dallara</td><td>Italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>de_tomaso-alfa_romeo</td><td>De Tomaso-Alfa Romeo</td><td>Italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>del_roy</td><td>Del Roy</td><td>American</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>gordini</td><td>Gordini</td><td>French</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>larrousse</td><td>Larrousse</td><td>French</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>lds</td><td>LDS</td><td>South African</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>lotus-borgward</td><td>Lotus-Borgward</td><td>British</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>marussia</td><td>Marussia</td><td>Russian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>merzario</td><td>Merzario</td><td>Italian</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>parnelli</td><td>Parnelli</td><td>American</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>sauber</td><td>Sauber</td><td>Swiss</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bmw_sauber</td><td>BMW Sauber</td><td>German</td><td>2026-07-16T13:56:58.853Z</td><td>dbfs:/Volumes/formula1/landi ...
